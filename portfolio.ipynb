# %%
import portfolio as Pf
import matplotlib.pyplot as plt

# %%
code = [1808, 1898, 2428, 7224]
units = [100, 100, 100, 300]

# %%
pf = Pf.Portfolio(code, units)

# %%
pf.add(9437, 600)

# %%
pf[9437] = 1200

# %%
pf[9437]
# Out:
# 1200

# %%
pf.remove(7224)

# %%
pf.plot()

# %%
pf.subplots()

# %%
pf.total()
